# %%
# pip install --pre astroquery

from astroquery.esa.xmm_newton import XMMNewton

obs_id = "0864960101"
XMMNewton.download_data(obs_id, level='PPS')
# Out:
# INFO: Found cached file 0864960101.tar. [astroquery.query]

# %%
import tarfile
import os

with tarfile.open("0864960101.tar") as tar:
    tar.extractall("xmm_data_0864960101")

print("✅ Extracted to ./xmm_data_0864960101")
# Out:
# ✅ Extracted to ./xmm_data_0864960101

# %%
import os

# Set your extracted folder path
data_dir = "xmm_data_0864960101"  # update if different

# Recursively find all .FTZ files
ftz_files = []
for root, dirs, files in os.walk(data_dir):
    for file in files:
        if file.lower().endswith(".ftz"):
            full_path = os.path.join(root, file)
            ftz_files.append(full_path)

# Print the results
print(f"🔍 Found {len(ftz_files)} .FTZ files:\n")
for path in ftz_files:
    print(path)
# Out:
# 🔍 Found 214 .FTZ files:
#
# xmm_data_0864960101/0864960101/pps/P0864960101PNS003TIEVLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S1322A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCTSR8002.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000F0001A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000DETMSK1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SBSPEC1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004EVENLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OBSMLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SRCLI_0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS006FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCTSR8003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS011FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000DETMSK5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMX000LSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCTSR8001.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000BKGMAP1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000FIBIS30000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OIMAGE8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000MEXPMP3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004DSPHIS1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005BGSPEC1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002EXPMAP1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000BKGMAP5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001EXPMAP5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2246A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000FIBIS20000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OBKGMP8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000MEXPMP5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000SRCTSR8009.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000BKGMAP3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OMSRLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SBSPEC2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS009FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000SRCSUM0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002EXPMAP3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001MIEVLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S9053A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000MEXPMP1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2297A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCTSR8007.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005ORDIMG0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS008SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001IMAGE_4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OBX000CALIND0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001IMAGE_8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000DETMSK3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OBMSLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OBX000REFCAT0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002FBKTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002IMAGE_2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S5114B0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004BGSPEC2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS012FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S8065A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2349A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS011SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000MEXPMP5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004BGMODL1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS006SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101PNX000SRCTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000BKGMAP3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002TIEVLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005RSPMAT2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SRCTSR0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004WREMAT2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OBX000ATTTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCARF0001.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000FOVSUM0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S1345A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S9055A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OEXPMP8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005FBKTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000SIBIS20000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S1297A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001EXPMAP1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000MEXPMP1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S9028A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OBX000RADMON0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000DETMSK3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SRSPEC1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004WFSPEC1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCARF0002.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2125A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCARF0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS007FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS010FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRSPEC0007.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101PNS003SRCARF0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005BGMODL2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002IMAGE_4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRSPEC0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000DETMSK1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000SRCHD_0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101PNS003SRCTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005WREMAT1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004RSPMAT1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCARF0007.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002IMAGE_8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101PNS003SRSPEC0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001IMAGE_2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2328A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001FBKTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRSPEC0002.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000DETMSK5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SRBTSR0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S0001A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002EXPMAP5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS012SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000BKGMAP1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001BGSPEC0009.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005WFSPEC2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SRSPEC2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000MEXPMP3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004EXPMAP0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001EXPMAP3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002MIEVLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS008FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRSPEC0001.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000SIBIS30000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000BKGMAP5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005IMAGE_0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101RGX000FLUXED1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000MEXPMP2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SRCLI_0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000BKGMAP4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS012FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OBX000PINDEX0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005EVENLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCARF0009.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S9013A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SBSPEC1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004BGSPEC1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS009FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OBLSLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000DETMSK4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005DSPHIS1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMX000LSISWSM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OBX000ORBTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002IMAGE_1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001BGSPEC0007.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000FHMXBB0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000F0012B0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002IMAGE_3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101PNS003BGSPEC0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001BGSPEC0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001IMAGE_5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SBSPEC2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001BGSPEC0002.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS007SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2327A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000DETMSK2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS010SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRSPEC0009.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S9030A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002EXPMAP2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005BGSPEC2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX000OSNSMP8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS011FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS006FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000MEXPMP4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S1284A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001BGSPEC0001.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001EXPMAP4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001EXPMAP8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004ORDIMG0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000BKGMAP2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2356A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004FBKTSR0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001IMAGE_1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS008FSIMAGM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005WREMAT2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S1252A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SRCTSR0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004RSPMAT2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000SRCTSR8007.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2321A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005BGMODL1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S0012B0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000DETMSK2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005WFSPEC1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000MEXPMP4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SRSPEC1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS009SWSRLIM000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCTSR8009.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2X000BKGMAP2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001EXPMAP2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS010FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005SRBTSR0003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2293A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000MEXPMP2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMS007FIMAG_M000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000BKGMAP4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005RSPMAT1003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002EXPMAP4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004WREMAT1000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S1305A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000SRCTSR8001.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101EPX0003COLIM8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004BGMODL2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002EXPMAP8000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004IMAGE_0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1S001IMAGE_3000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000SHMXBB0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000SRCTSR8003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000DETMSK4000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S2298A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R2S005EXPMAP0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMX000OBSMOS0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101CAX000S0015A0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004SRSPEC2003.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101OMX000OBSMLI0000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101R1S004WFSPEC2000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M2S002IMAGE_5000.FTZ
# xmm_data_0864960101/0864960101/pps/P0864960101M1X000SRCTSR8002.FTZ

# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# Load the likely light curve file
filename = "xmm_data_0864960101/0864960101/pps/P0864960101PNS003TIEVLI0000.FTZ"

with fits.open(filename) as hdul:
    hdul.info()  # To view all HDU names and structure

    # Look for column names
    print(hdul[1].columns)

    data = hdul[1].data
    time = data['TIME']           # Usually TIME is always present
    try:
        rate = data['RATE']       # Light curve photon count rate
    except KeyError:
        print("⚠️ 'RATE' column not found, showing available columns:")
        print(data.columns.names)

# Plot the light curve if RATE exists
if 'RATE' in data.columns.names:
    plt.figure(figsize=(10, 4))
    plt.plot(time, rate, drawstyle='steps-mid')
    plt.xlabel('Time (s)')
    plt.ylabel('Count Rate (cts/s)')
    plt.title('XMM Light Curve – GRS 1915+105')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Filename: xmm_data_0864960101/0864960101/pps/P0864960101PNS003TIEVLI0000.FTZ
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     151   ()
#   1  EVENTS        1 BinTableHDU    196   672337R x 14C   [D, I, I, I, I, J, J, I, I, J, B, I, B, B]
#   2  OFFSETS       1 BinTableHDU     96   0R x 1C   [B]
#   3  BADPIX04      1 BinTableHDU     98   0R x 5C   [I, I, I, I, I]
#   4  EXPOSU04      1 BinTableHDU    327   9039151R x 2C   [D, E]
#   5  DLIMAP04      1 BinTableHDU    287   200R x 2C   [J, J]
#   6  HKAUX04       1 BinTableHDU    286   451940R x 2C   [D, E]
#   7  STDGTI04      1 BinTableHDU    227   11R x 2C   [D, D]
#   8  CALINDEX      1 BinTableHDU     45   121R x 14C   [4A, 6A, 32A, I, 19A, 19A, 256A, 19A, J, 19A, 32A, 256A, 32A, 64A]
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 's'
#     name = 'RAWX'; format = 'I'; unit = 'pixel'
#     name = 'RAWY'; format = 'I'; unit = 'pixel'
#     name = 'DETX'; format = 'I'; unit = '0.05 arcsec'; coord_ref_point = 0; coord_inc = 1.38888888888889e-05
#     name = 'DETY'; format = 'I'; unit = '0.05 arcsec'; coord_ref_point = 0; coord_inc = 1.38888888888889e-05
#     name = 'X'; format = 'J'; unit = '0.05 arcsec'; null = -99999999; coord_type = 'RA---TAN'; coord_unit = 'deg'; coord_ref_point = 25921; coord_ref_value = 288.817041666667; coord_inc = -1.38888888888889e-05
#     name = 'Y'; format = 'J'; unit = '0.05 arcsec'; null = -99999999; coord_type = 'DEC--TAN'; coord_unit = 'deg'; coord_ref_point = 25921; coord_ref_value = 10.924; coord_inc = 1.38888888888889e-05
#     name = 'PHA'; format = 'I'; unit = 'channel'
#     name = 'PI'; format = 'I'; unit = 'eV'; null = -32768
#     name = 'FLAG'; format = 'J'
#     name = 'PATTERN'; format = 'B'; null = 13
#     name = 'PAT_ID'; format = 'I'; null = 32767
#     name = 'PAT_SEQ'; format = 'B'; null = 255
#     name = 'CCDNR'; format = 'B'
# )
# ⚠️ 'RATE' column not found, showing available columns:
# ['TIME', 'RAWX', 'RAWY', 'DETX', 'DETY', 'X', 'Y', 'PHA', 'PI', 'FLAG', 'PATTERN', 'PAT_ID', 'PAT_SEQ', 'CCDNR']

# %%
import os
from astropy.io import fits

# Directory containing your FTZ files
base_dir = "xmm_data_0864960101/0864960101/pps"

# To store matched files
matches = []

for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".FTZ"):
            filepath = os.path.join(root, file)
            try:
                with fits.open(filepath) as hdul:
                    if len(hdul) > 1 and hasattr(hdul[1], 'columns'):
                        columns = hdul[1].columns.names
                        if any(col in columns for col in ['RATE', 'COUNTS', 'TIME']):
                            matches.append({
                                'filename': file,
                                'columns': columns
                            })
            except Exception as e:
                print(f"⚠️ Could not read {file}: {e}")

# Show results
for match in matches:
    print(f"✅ Found: {match['filename']}")
    print(f"   Columns: {match['columns']}")
# Out:
# WARNING: VerifyWarning: Invalid keyword for column 15: Coordinate/axis type option (TCTYPn) must be a string of atmost 8 characters (got 'Dispersion Channel'). The invalid keyword will be ignored for the purpose of formatting this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 17: Coordinate/axis type option (TCTYPn) must be a string of atmost 8 characters (got 'Cross-dispersion Channel'). The invalid keyword will be ignored for the purpose of formatting this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 33: Column disp option (TDISPn) failed verification: Format K10 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 10: Column disp option (TDISPn) failed verification: Format K18 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 13: Column disp option (TDISPn) failed verification: Format K10 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 15: Column disp option (TDISPn) failed verification: Format K19 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 16: Column disp option (TDISPn) failed verification: Format K19 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 17: Column disp option (TDISPn) failed verification: Format K10 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 9: Column disp option (TDISPn) failed verification: Format K15 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 30: Column disp option (TDISPn) failed verification: Format K19 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 80: Column disp option (TDISPn) failed verification: Format K10 is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# ✅ Found: P0864960101PNS003TIEVLI0000.FTZ
#    Columns: ['TIME', 'RAWX', 'RAWY', 'DETX', 'DETY', 'X', 'Y', 'PHA', 'PI', 'FLAG', 'PATTERN', 'PAT_ID', 'PAT_SEQ', 'CCDNR']
# ✅ Found: P0864960101M1S001SRCTSR8002.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101R1S004SBSPEC1003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101R1S004EVENLI0000.FTZ
#    Columns: ['TIME', 'FLAG', 'BETA', 'XDSP', 'CHIPX', 'CHIPY', 'PHA', 'SHAPE', 'GRADE', 'PI', 'CCDNR', 'BETA_CORR', 'XDSP_CORR', 'M_LAMBDA', 'BETA_CHANNEL', 'MLAMBDA_CHANNEL', 'XDSP_CHANNEL']
# ✅ Found: P0864960101R1S004SRCLI_0000.FTZ
#    Columns: ['INDEX', 'LABEL', 'RA', 'DEC', 'RATE', 'DELTA_DISP', 'DELTA_XDSP', 'FOV_PHI', 'FOV_R', 'CONFUSION', 'PROCESS', 'BKG_EXCLUDE', 'FIXED_ON_SKY', 'EPIC_FILE', 'FLAG']
# ✅ Found: P0864960101M1S001SRCTSR8003.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101M1S001SRCTSR8001.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101R1S004DSPHIS1003.FTZ
#    Columns: ['COUNTS', 'XDSP_CORR']
# ✅ Found: P0864960101R2S005BGSPEC1003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1X000SRCTSR8009.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE', 'RATE1', 'RATE1_ERR', 'BACK1V', 'BACK1E', 'RATE2', 'RATE2_ERR', 'BACK2V', 'BACK2E', 'RATE3', 'RATE3_ERR', 'BACK3V', 'BACK3E', 'RATE4', 'RATE4_ERR', 'BACK4V', 'BACK4E', 'RATE5', 'RATE5_ERR', 'BACK5V', 'BACK5E', 'EXP_ID', 'TIMEDEL']
# ✅ Found: P0864960101EPX000OMSRLI0000.FTZ
#    Columns: ['ML_ID_SRC', 'BOX_ID_SRC', 'ID_INST', 'ID_BAND', 'ID_CLUSTER', 'SCTS', 'SCTS_ERR', 'X_IMA', 'X_IMA_ERR', 'Y_IMA', 'Y_IMA_ERR', 'EXT', 'EXT_ERR', 'DET_ML', 'EXT_ML', 'BG_MAP', 'EXP_MAP', 'FLUX', 'FLUX_ERR', 'RATE', 'RATE_ERR', 'RA', 'DEC', 'RADEC_ERR', 'LII', 'BII', 'RAWX', 'RAWY', 'OFFAX', 'CCDNR', 'HR1', 'HR1_ERR', 'HR2', 'HR2_ERR', 'HR3', 'HR3_ERR', 'HR4', 'HR4_ERR', 'CUTRAD', 'MASKFRAC', 'EEF', 'VIGNETTING', 'ONTIME', 'PILEUP', 'DIST_NN', 'FLAG']
# ✅ Found: P0864960101R2S005SBSPEC2003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1S001MIEVLI0000.FTZ
#    Columns: ['TIME', 'RAWX', 'RAWY', 'DETX', 'DETY', 'X', 'Y', 'PHA', 'PI', 'FLAG', 'PATTERN', 'CCDNR']
# ✅ Found: P0864960101M1S001SRCTSR8007.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101OMS008SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101EPX000OBMSLI0000.FTZ
#    Columns: ['BOX_ID_SRC', 'ID_INST', 'ID_BAND', 'SCTS', 'SCTS_ERR', 'BOX_CTS', 'X_IMA', 'X_IMA_ERR', 'Y_IMA', 'Y_IMA_ERR', 'LIKE', 'BG_MAP', 'BG_RAW', 'EXP_MAP', 'FLUX', 'FLUX_ERR', 'RATE', 'RATE_ERR', 'RA', 'DEC', 'RADEC_ERR', 'LII', 'BII', 'HR1', 'HR1_ERR', 'HR2', 'HR2_ERR', 'HR3', 'HR3_ERR', 'VIGNETTING', 'BOX_SIZE', 'EEF', 'DIST_NN']
# ✅ Found: P0864960101M2S002FBKTSR0000.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'T_ELAPSED']
# ✅ Found: P0864960101R1S004BGSPEC2003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101OMS011SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101R1S004BGMODL1000.FTZ
#    Columns: ['CHANNEL', 'RATE', 'STAT_ERR', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101OMS006SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101PNX000SRCTSR0000.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE', 'RATE2', 'RATE2_ERR', 'BACK2V', 'BACK2E', 'RATE3', 'RATE3_ERR', 'BACK3V', 'BACK3E', 'RATE4', 'RATE4_ERR', 'BACK4V', 'BACK4E', 'RATE100', 'RATE100_ERR', 'BACK100V', 'BACK100E', 'EXP_ID', 'TIMEDEL']
# ✅ Found: P0864960101M2S002TIEVLI0000.FTZ
#    Columns: ['TIME', 'RAWX', 'PHA', 'PI', 'FLAG', 'PATTERN', 'CCDNR']
# ✅ Found: P0864960101R2S005SRCTSR0003.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'COUNTS', 'ERRCTS', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101OBX000ATTTSR0000.FTZ
#    Columns: ['TIME', 'AHFRA', 'AHFDEC', 'AHFPA', 'OMRA', 'OMDEC', 'OMPA', 'DAHFPNT', 'DOMPNT', 'DAHFOM']
# ✅ Found: P0864960101R2S005FBKTSR0000.FTZ
#    Columns: ['RATE', 'ERROR', 'TIME']
# ✅ Found: P0864960101OBX000RADMON0000.FTZ
#    Columns: ['FTCOARSE', 'FTFINE', 'FRAME', 'NLE0', 'NLE1', 'NLE2', 'NHE0', 'NHE1', 'NHE2', 'NHEC', 'WFSTAT', 'EVALCADD', 'EVALCNO', 'TIME', 'MJD', 'TIMECAL']
# ✅ Found: P0864960101R1S004SRSPEC1003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'STAT_ERR', 'QUALITY', 'AREASCAL']
# ✅ Found: P0864960101R1S004WFSPEC1000.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1S001SRSPEC0007.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'GROUPING', 'QUALITY']
# ✅ Found: P0864960101R2S005BGMODL2000.FTZ
#    Columns: ['CHANNEL', 'RATE', 'STAT_ERR', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1S001SRSPEC0003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'GROUPING', 'QUALITY']
# ✅ Found: P0864960101PNS003SRCTSR0000.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101PNS003SRSPEC0000.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'GROUPING', 'QUALITY']
# ✅ Found: P0864960101M1S001FBKTSR0000.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'T_ELAPSED']
# ✅ Found: P0864960101M1S001SRSPEC0002.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'GROUPING', 'QUALITY']
# ✅ Found: P0864960101R1S004SRBTSR0003.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'COUNTS', 'ERRCTS', 'FRACEXP']
# ✅ Found: P0864960101OMS012SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101M1S001BGSPEC0009.FTZ
#    Columns: ['CHANNEL', 'COUNTS']
# ✅ Found: P0864960101R2S005WFSPEC2000.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101R2S005SRSPEC2003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'STAT_ERR', 'QUALITY', 'AREASCAL']
# ✅ Found: P0864960101M2S002MIEVLI0000.FTZ
#    Columns: ['TIME', 'RAWX', 'RAWY', 'DETX', 'DETY', 'X', 'Y', 'PHA', 'PI', 'FLAG', 'PATTERN', 'CCDNR']
# ✅ Found: P0864960101M1S001SRSPEC0001.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'GROUPING', 'QUALITY']
# ✅ Found: P0864960101R2S005SRCLI_0000.FTZ
#    Columns: ['INDEX', 'LABEL', 'RA', 'DEC', 'RATE', 'DELTA_DISP', 'DELTA_XDSP', 'FOV_PHI', 'FOV_R', 'CONFUSION', 'PROCESS', 'BKG_EXCLUDE', 'FIXED_ON_SKY', 'EPIC_FILE', 'FLAG']
# ✅ Found: P0864960101R2S005EVENLI0000.FTZ
#    Columns: ['TIME', 'FLAG', 'BETA', 'XDSP', 'CHIPX', 'CHIPY', 'PHA', 'SHAPE', 'GRADE', 'PI', 'CCDNR', 'BETA_CORR', 'XDSP_CORR', 'M_LAMBDA', 'BETA_CHANNEL', 'MLAMBDA_CHANNEL', 'XDSP_CHANNEL']
# ✅ Found: P0864960101R2S005SBSPEC1003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101R1S004BGSPEC1003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101EPX000OBLSLI0000.FTZ
#    Columns: ['BOX_ID_SRC', 'ID_INST', 'ID_BAND', 'SCTS', 'SCTS_ERR', 'BOX_CTS', 'X_IMA', 'X_IMA_ERR', 'Y_IMA', 'Y_IMA_ERR', 'LIKE', 'BG_MAP', 'BG_RAW', 'EXP_MAP', 'FLUX', 'FLUX_ERR', 'RATE', 'RATE_ERR', 'RA', 'DEC', 'RADEC_ERR', 'LII', 'BII', 'HR1', 'HR1_ERR', 'HR2', 'HR2_ERR', 'HR3', 'HR3_ERR', 'VIGNETTING', 'BOX_SIZE', 'EEF', 'DIST_NN']
# ✅ Found: P0864960101R2S005DSPHIS1003.FTZ
#    Columns: ['COUNTS', 'XDSP_CORR']
# ✅ Found: P0864960101OMX000LSISWSM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'RA', 'DEC', 'SRC_ID']
# ✅ Found: P0864960101OBX000ORBTSR0000.FTZ
#    Columns: ['TIME', 'GEI_X', 'GEI_Y', 'GEI_Z', 'GSE_X', 'GSE_Y', 'GSE_Z', 'VX', 'VY', 'VZ']
# ✅ Found: P0864960101M1S001BGSPEC0007.FTZ
#    Columns: ['CHANNEL', 'COUNTS']
# ✅ Found: P0864960101PNS003BGSPEC0000.FTZ
#    Columns: ['CHANNEL', 'COUNTS']
# ✅ Found: P0864960101M1S001BGSPEC0003.FTZ
#    Columns: ['CHANNEL', 'COUNTS']
# ✅ Found: P0864960101R1S004SBSPEC2003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1S001BGSPEC0002.FTZ
#    Columns: ['CHANNEL', 'COUNTS']
# ✅ Found: P0864960101OMS007SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101OMS010SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101M1S001SRSPEC0009.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'GROUPING', 'QUALITY']
# ✅ Found: P0864960101R2S005BGSPEC2003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1S001BGSPEC0001.FTZ
#    Columns: ['CHANNEL', 'COUNTS']
# ✅ Found: P0864960101R1S004FBKTSR0000.FTZ
#    Columns: ['RATE', 'ERROR', 'TIME']
# ✅ Found: P0864960101R1S004SRCTSR0003.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'COUNTS', 'ERRCTS', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101M1X000SRCTSR8007.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE', 'RATE1', 'RATE1_ERR', 'BACK1V', 'BACK1E', 'RATE2', 'RATE2_ERR', 'BACK2V', 'BACK2E', 'RATE3', 'RATE3_ERR', 'BACK3V', 'BACK3E', 'RATE4', 'RATE4_ERR', 'BACK4V', 'BACK4E', 'RATE5', 'RATE5_ERR', 'BACK5V', 'BACK5E', 'EXP_ID', 'TIMEDEL']
# ✅ Found: P0864960101R2S005BGMODL1000.FTZ
#    Columns: ['CHANNEL', 'RATE', 'STAT_ERR', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101R2S005WFSPEC1000.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101R2S005SRSPEC1003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'STAT_ERR', 'QUALITY', 'AREASCAL']
# ✅ Found: P0864960101OMS009SWSRLIM000.FTZ
#    Columns: ['SRCNUM', 'XPOS', 'YPOS', 'POSERR', 'RA', 'DEC', 'RA_CORR', 'DEC_CORR', 'LII', 'BII', 'RATE', 'RATE_ERR', 'BACKGROUND_RATE', 'BKG_RATE_ERR', 'SIGNIFICANCE', 'CORR_RATE', 'CORR_RATE_ERR', 'CORR_BACKGROUND_RATE', 'CORR_BKG_RATE_ERR', 'PSF2_CORR', 'PSF1_CORR', 'SPB_COILOSS', 'BK_COILOSS', 'MAG', 'MAGERR', 'NOPIXELS', 'APERTURE', 'FWHM_MAJ', 'FWHM_MAJ_ERR', 'FWHM_MIN', 'FWHM_MIN_ERR', 'PA', 'PA_ERR', 'QFLAG', 'CFLAG', 'EFLAG', 'SRC_ID']
# ✅ Found: P0864960101M1S001SRCTSR8009.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE']
# ✅ Found: P0864960101R2S005SRBTSR0003.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'COUNTS', 'ERRCTS', 'FRACEXP']
# ✅ Found: P0864960101M1X000SRCTSR8001.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE', 'RATE1', 'RATE1_ERR', 'BACK1V', 'BACK1E', 'RATE2', 'RATE2_ERR', 'BACK2V', 'BACK2E', 'RATE3', 'RATE3_ERR', 'BACK3V', 'BACK3E', 'RATE4', 'RATE4_ERR', 'BACK4V', 'BACK4E', 'RATE5', 'RATE5_ERR', 'BACK5V', 'BACK5E', 'EXP_ID', 'TIMEDEL']
# ✅ Found: P0864960101R1S004BGMODL2000.FTZ
#    Columns: ['CHANNEL', 'RATE', 'STAT_ERR', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1X000SRCTSR8003.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE', 'RATE1', 'RATE1_ERR', 'BACK1V', 'BACK1E', 'RATE2', 'RATE2_ERR', 'BACK2V', 'BACK2E', 'RATE3', 'RATE3_ERR', 'BACK3V', 'BACK3E', 'RATE4', 'RATE4_ERR', 'BACK4V', 'BACK4E', 'RATE5', 'RATE5_ERR', 'BACK5V', 'BACK5E', 'EXP_ID', 'TIMEDEL']
# ✅ Found: P0864960101R1S004SRSPEC2003.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'STAT_ERR', 'QUALITY', 'AREASCAL']
# ✅ Found: P0864960101R1S004WFSPEC2000.FTZ
#    Columns: ['CHANNEL', 'COUNTS', 'QUALITY', 'AREASCAL', 'BACKSCAL']
# ✅ Found: P0864960101M1X000SRCTSR8002.FTZ
#    Columns: ['TIME', 'RATE', 'ERROR', 'FRACEXP', 'BACKV', 'BACKE', 'RATE1', 'RATE1_ERR', 'BACK1V', 'BACK1E', 'RATE2', 'RATE2_ERR', 'BACK2V', 'BACK2E', 'RATE3', 'RATE3_ERR', 'BACK3V', 'BACK3E', 'RATE4', 'RATE4_ERR', 'BACK4V', 'BACK4E', 'RATE5', 'RATE5_ERR', 'BACK5V', 'BACK5E', 'EXP_ID', 'TIMEDEL']

# %%
light_curve_files = [
    "P0864960101M1S001SRCTSR8001.FTZ",
    "P0864960101M1S001SRCTSR8002.FTZ",
    "P0864960101M1S001SRCTSR8003.FTZ",
    "P0864960101M1S001SRCTSR8007.FTZ",
    "P0864960101M1S001SRCTSR8009.FTZ",
    "P0864960101PNX000SRCTSR0000.FTZ",
    "P0864960101R2S005SRCTSR0003.FTZ",
    "P0864960101R2S005SRBTSR0003.FTZ",
    "P0864960101R1S004SRCTSR0003.FTZ"
]

# %%
import os
from astropy.io import fits
import matplotlib.pyplot as plt

# ✅ Your chosen light curve FITS file
filename = "xmm_data_0864960101/0864960101/pps/P0864960101M1S001SRCTSR8002.FTZ"

# Open and read the FITS file
with fits.open(filename) as hdul:
    data = hdul[1].data
    time = data['TIME']
    rate = data['RATE']
    error = data['ERROR'] if 'ERROR' in data.columns.names else None

# 📊 Plot light curve
plt.figure(figsize=(12, 4))
plt.plot(time, rate, drawstyle='steps-mid', label='Count Rate')
if error is not None:
    plt.fill_between(time, rate - error, rate + error, step='mid', alpha=0.3, label='Error')
plt.xlabel('Time (s)')
plt.ylabel('Count Rate (cts/s)')
plt.title('XMM-Newton Light Curve – GRS 1915+105')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
from scipy.signal import welch
import numpy as np

# Remove any NaNs or gaps
valid = np.isfinite(rate)
time_clean = time[valid]
rate_clean = rate[valid]

# Estimate sampling rate
dt = np.median(np.diff(time_clean))
fs = 1.0 / dt  # sampling frequency (Hz)

# Compute Power Spectral Density using Welch's method
frequencies, power = welch(rate_clean, fs=fs, nperseg=256)

# Plot the Power Spectrum
plt.figure(figsize=(10, 4))
plt.semilogy(frequencies, power)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Power Spectral Density – GRS 1915+105")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/scipy/signal/_spectral_py.py:600: UserWarning: nperseg = 256 is greater than input length  = 20, using nperseg = 20
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,

# %%
from statsmodels.tsa.stattools import acf

autocorr = acf(rate_clean, nlags=100, fft=True)

plt.figure(figsize=(8, 3))
plt.plot(autocorr)
plt.title("Autocorrelation (ACF)")
plt.xlabel("Lag")
plt.ylabel("Correlation")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 3))
plt.hist(rate_clean, bins=50, alpha=0.7)
plt.title("Flux Histogram")
plt.xlabel("Count Rate")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# I want to try these can you share the code 

# Try Lomb-Scargle Periodogram:
# More robust for uneven or noisy time series.

# Fit a Lorentzian to the PSD peak:
# That's the standard way to confirm a QPO and estimate its centroid frequency and width (Q-factor).
